# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/WA_Fn-UseC_-HR-Employee-Attrition.csv'
df = pd.read_csv(file_path)

df.head()
file_path = '/content/drive/MyDrive/AttritionProject/WA_Fn-UseC_-HR-Employee-Attrition.csv'

# %%
# 1. SatisfactionIndex – Average of 3 satisfaction metrics
df['SatisfactionIndex'] = (
    df['JobSatisfaction'] + df['EnvironmentSatisfaction'] + df['RelationshipSatisfaction']
) / 3

# 2. TenureBucket – Grouping YearsAtCompany
df['TenureBucket'] = pd.cut(
    df['YearsAtCompany'],
    bins=[0, 2, 5, 10, df['YearsAtCompany'].max()],
    labels=['<2yrs', '2–5yrs', '5–10yrs', '10yrs+']
)

# 3. WorkBalanceScore – Combining WorkLifeBalance & JobInvolvement
df['WorkBalanceScore'] = (
    df['WorkLifeBalance'] + df['JobInvolvement']
) / 2

# 4. IncomeLevel – Binned MonthlyIncome
df['IncomeLevel'] = pd.qcut(df['MonthlyIncome'], q=3, labels=['Low', 'Medium', 'High'])

# 5. Overworked – Flag if experience outside company > 5 years
df['Overworked'] = (df['TotalWorkingYears'] - df['YearsAtCompany']) > 5
df.to_csv('/content/drive/MyDrive/employee_attrition_modified.csv', index=False)

# %%
import numpy as np

# Define some dummy feedback samples
comments = [
    "I feel overworked and underappreciated.",
    "The team environment is great, I’m satisfied with my job.",
    "Management never listens to suggestions.",
    "Workload is balanced and the projects are interesting.",
    "I am actively looking for a new job.",
    "My manager supports my growth and learning.",
    "There is no room for promotion.",
    "Company policies are transparent and fair.",
    "Feeling stuck in the same role for too long.",
    "I enjoy my work and the team spirit is high."
]

# Randomly assign one to each employee
np.random.seed(42)  # for reproducibility
df['FeedbackComment'] = np.random.choice(comments, size=len(df))


# Map comments to wellness category
sentiment_map = {
    "I feel overworked and underappreciated.": "At Risk",
    "The team environment is great, I’m satisfied with my job.": "Thriving",
    "Management never listens to suggestions.": "At Risk",
    "Workload is balanced and the projects are interesting.": "Thriving",
    "I am actively looking for a new job.": "At Risk",
    "My manager supports my growth and learning.": "Thriving",
    "There is no room for promotion.": "At Risk",
    "Company policies are transparent and fair.": "Stable",
    "Feeling stuck in the same role for too long.": "Stable",
    "I enjoy my work and the team spirit is high.": "Thriving"
}

df['WellnessCategory'] = df['FeedbackComment'].map(sentiment_map)


df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
# Add dummy attendance data
np.random.seed(42)
df['AbsentDaysLastYear'] = np.random.poisson(lam=5, size=len(df))
df['LateComingCount'] = np.random.randint(0, 10, size=len(df))
df['WorkedOvertimeDays'] = np.random.randint(0, 20, size=len(df))
# Define exit comments
exit_comments = [
    "Left due to lack of growth opportunities.",
    "Relocated to another city.",
    "Found better compensation elsewhere.",
    "Burnout from excessive workload.",
    "Conflict with management.",
    "Wanted to switch careers.",
    "No work-life balance.",
    "Went for higher education.",
    "Unfair promotion policies.",
    "Work culture was toxic."
]

# Add exit comment only for those who left
df['ExitComment'] = np.where(
    df['Attrition'] == 'Yes',
    np.random.choice(exit_comments, size=df.shape[0]),
    ""
)

survey_texts = [
    "The workload is fair, and my manager checks in regularly.",
    "Sometimes I feel like my work is undervalued.",
    "I don’t get enough opportunities to work on interesting projects.",
    "Team meetings are helpful and collaborative.",
    "Too many processes make things slow.",
    "I appreciate the flexibility to work from home.",
    "There’s no clear path for promotion.",
    "I feel disconnected from leadership.",
    "The company is investing in employee wellbeing.",
    "HR is responsive and professional."
]

df['SurveyText'] = np.random.choice(survey_texts, size=len(df))

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  WorkBalanceScore IncomeLevel  Overworked  \
# ...

# %%
df.shape
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# SatisfactionIndex: Average of three satisfaction scores
df['SatisfactionIndex'] = df[['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']].mean(axis=1)

# TenureBucket: Grouping employees based on years at company
df['TenureBucket'] = pd.cut(df['YearsAtCompany'], bins=[0, 2, 5, 10, 40], labels=['<2 yrs', '2–5 yrs', '5–10 yrs', '10+ yrs'])

# WorkBalanceScore: Based on WorkLifeBalance and OverTime
df['WorkBalanceScore'] = df['WorkLifeBalance'] - df['OverTime'].map({'Yes': 1, 'No': 0})

# IncomeLevel: Categorizing income
df['IncomeLevel'] = pd.cut(df['MonthlyIncome'], bins=[0, 3000, 7000, 15000, df['MonthlyIncome'].max()],
                           labels=['Low', 'Medium', 'High', 'Very High'])

# Overworked: if working too many years and having Overtime
df['Overworked'] = ((df['TotalWorkingYears'] > 10) & (df['OverTime'] == 'Yes')).astype(int)

# FeedbackComment (just a mock-up): based on satisfaction
df['FeedbackComment'] = df['SatisfactionIndex'].apply(lambda x: 'Unhappy' if x < 2 else 'Neutral' if x < 3.5 else 'Happy')

# WellnessCategory: based on WorkLifeBalance
df['WellnessCategory'] = df['WorkLifeBalance'].map({1: 'Poor', 2: 'Fair', 3: 'Good', 4: 'Excellent'})

# Mock values for missing features (for demo purposes)
import numpy as np
np.random.seed(42)
df['AbsentDaysLastYear'] = np.random.randint(0, 15, df.shape[0])
df['LateComingCount'] = np.random.randint(0, 10, df.shape[0])
df['WorkedOvertimeDays'] = np.where(df['OverTime'] == 'Yes', np.random.randint(10, 40, df.shape[0]), 0)
df['ExitComment'] = df['Attrition'].map({'Yes': 'Left due to dissatisfaction', 'No': 'Still working'})
df['SurveyText'] = df['JobSatisfaction'].map({1: 'Needs improvement', 2: 'Average', 3: 'Satisfied', 4: 'Very satisfied'})

# %%
print(df.shape)           # Should be (rows, 47)
print(df.columns.tolist())  # To verify all new columns
# Out:
# (1470, 47)
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'SatisfactionIndex', 'TenureBucket', 'WorkBalanceScore', 'IncomeLevel', 'Overworked', 'FeedbackComment', 'WellnessCategory', 'AbsentDaysLastYear', 'LateComingCount', 'WorkedOvertimeDays', 'ExitComment', 'SurveyText']

# %%
# Detecting outliers using IQR method
Q1 = df_cleaned[numerical_cols].quantile(0.25)
Q3 = df_cleaned[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

# Filtering out outliers
df_cleaned = df_cleaned[~((df_cleaned[numerical_cols] < (Q1 - 1.5 * IQR)) | (df_cleaned[numerical_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Impute numerical columns with the median
numerical_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
df_cleaned[numerical_cols] = df_cleaned[numerical_cols].fillna(df_cleaned[numerical_cols].median())

# Impute categorical columns with the mode
categorical_cols = df_cleaned.select_dtypes(include=['object']).columns
df_cleaned[categorical_cols] = df_cleaned[categorical_cols].fillna(df_cleaned[categorical_cols].mode().iloc[0])
# Out:
# <ipython-input-21-29fe898aa740>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[numerical_cols] = df_cleaned[numerical_cols].fillna(df_cleaned[numerical_cols].median())
# <ipython-input-21-29fe898aa740>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[categorical_cols] = df_cleaned[categorical_cols].fillna(df_cleaned[categorical_cols].mode().iloc[0])

# %%
df_cleaned = df_cleaned.drop_duplicates()

# %%
# Define a mapping dictionary for job title standardization
job_title_mapping = {
    "SWE": "Software Engineer",
    "Software Developer": "Software Engineer",
    "Data Scientist": "Data Analyst",
    # Add more mappings as needed
}

df_cleaned['JobRole'] = df_cleaned['JobRole'].replace(job_title_mapping)

# %%
# Example: Convert 'JoinDate' to a standard format (YYYY-MM-DD)
df_cleaned['JoinDate'] = pd.to_datetime(df_cleaned['JoinDate'], format='%d/%m/%Y').dt.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'JoinDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-770e98fe8225> in <cell line: 0>()
#       1 # Example: Convert 'JoinDate' to a standard format (YYYY-MM-DD)
# ...

# %%
# Check the columns in your dataset
print(df_cleaned.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'SatisfactionIndex', 'TenureBucket',
#        'WorkBalanceScore', 'IncomeLevel', 'Overworked', 'FeedbackComment',
#        'WellnessCategory', 'AbsentDaysLastYear', 'LateComingCount',
#        'WorkedOvertimeDays', 'ExitComment', 'SurveyText'],
#       dtype='object')

# %%
df['EngagementScore'] = df['JobSatisfaction'] * df['WorkLifeBalance']

df['PerformanceScore'] = df['PerformanceRating']  # Assuming performance rating exists
df['Bonus'] = df['MonthlyIncome'] * 0.1  # For example, assume 10% as bonus of monthly income

df['WellnessProgramParticipation'] = df['WellnessCategory'].apply(lambda x: 1 if x == 'Participating' else 0)

df['WorkHoursPerWeek'] = 40  # Or other values based on the role

df['ExitReason'] = df['ExitComment'].apply(lambda x: 'Voluntary' if 'Resignation' in x else 'Involuntary')


df['ManagerPerformance'] = df.groupby('JobRole')['JobSatisfaction'].transform('mean')


df['TenureCategory'] = pd.cut(df['YearsAtCompany'], bins=[0, 1, 3, 5, 10, 20, 30],
                              labels=['New Hire', '1-3 Years', '3-5 Years', '5-10 Years', '10-20 Years', 'Veteran'])

# %%
len(df.columns)
# Out:
# 55

# %%
# Drop columns with more than 50% missing values
threshold = 0.5
df = df[df.columns[df.isnull().mean() < threshold]]

# %%
# Impute numerical columns with median
df['column_name'] = df['column_name'].fillna(df['column_name'].median())

# Impute categorical columns with mode
df['categorical_column'] = df['categorical_column'].fillna(df['categorical_column'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6da5f62010fd> in <cell line: 0>()
#       1 # Impute numerical columns with median
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'SatisfactionIndex', 'TenureBucket',
#        'WorkBalanceScore', 'IncomeLevel', 'Overworked', 'FeedbackComment',
#        'WellnessCategory', 'AbsentDaysLastYear', 'LateComingCount',
#        'WorkedOvertimeDays', 'ExitComment', 'SurveyText', 'EngagementScore',
# ...

# %%
print(df.isnull().sum())
# Out:
# Age                              0
# Attrition                        0
# BusinessTravel                   0
# DailyRate                        0
# Department                       0
# DistanceFromHome                 0
# Education                        0
# EducationField                   0
# EmployeeCount                    0
# EmployeeNumber                   0
# EnvironmentSatisfaction          0
# Gender                           0
# HourlyRate                       0
# JobInvolvement                   0
# JobLevel                         0
# JobRole                          0
# JobSatisfaction                  0
# MaritalStatus                    0
# MonthlyIncome                    0
# MonthlyRate                      0
# NumCompaniesWorked               0
# Over18                           0
# OverTime                         0
# PercentSalaryHike                0
# PerformanceRating                0
# RelationshipSatisfaction         0
# StandardHours                    0
# ...

# %%
df['TenureBucket'] = df['TenureBucket'].fillna(df['TenureBucket'].mode()[0])
df['TenureCategory'] = df['TenureCategory'].fillna(df['TenureCategory'].mode()[0])

# %%
df.duplicated().sum()  # Check for duplicates
df = df.drop_duplicates()  # Remove duplicates if any

# %%
df['JobRole'] = df['JobRole'].replace({'Software Engineer': 'SWE', 'Senior Software Engineer': 'Senior SWE'})

# %%
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
Q1 = df['Attrition'].quantile(0.25)
Q3 = df['Attrition'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Attrition'] >= (Q1 - 1.5 * IQR)) & (df['Attrition'] <= (Q3 + 1.5 * IQR))]

# %%
df['HireDate'] = pd.to_datetime(df['HireDate'])
df['TenureInYears'] = (pd.to_datetime('today') - df['HireDate']).dt.days / 365
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HireDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-2f1608dff4a9> in <cell line: 0>()
# ----> 1 df['HireDate'] = pd.to_datetime(df['HireDate'])
# ...

# %%
df['JoiningDate'] = pd.to_datetime(df['JoiningDate'])
df['TenureInYears'] = (pd.to_datetime('today') - df['JoiningDate']).dt.days / 365
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'JoiningDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-607e55c50611> in <cell line: 0>()
# ----> 1 df['JoiningDate'] = pd.to_datetime(df['JoiningDate'])
# ...

# %%
print(df.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'SatisfactionIndex', 'TenureBucket',
#        'WorkBalanceScore', 'IncomeLevel', 'Overworked', 'FeedbackComment',
#        'WellnessCategory', 'AbsentDaysLastYear', 'LateComingCount',
#        'WorkedOvertimeDays', 'ExitComment', 'SurveyText', 'EngagementScore',
# ...

# %%
df['TenureInYears'] = df['YearsAtCompany']

# %%
# One-Hot Encoding for categorical columns
categorical_cols = ['BusinessTravel', 'Department', 'Education', 'EducationField',
                    'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 'StockOptionLevel',
                    'WorkLifeBalance', 'TenureBucket', 'IncomeLevel', 'WellnessCategory',
                    'ExitReason', 'ManagerPerformance', 'TenureCategory']

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

# List of numerical columns to scale
numerical_cols = ['Age', 'DailyRate', 'DistanceFromHome', 'EnvironmentSatisfaction',
                  'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
                  'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
                  'PerformanceRating', 'RelationshipSatisfaction', 'TrainingTimesLastYear',
                  'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
                  'YearsWithCurrManager', 'SatisfactionIndex', 'WorkBalanceScore', 'AbsentDaysLastYear',
                  'LateComingCount', 'WorkedOvertimeDays', 'EngagementScore', 'PerformanceScore',
                  'Bonus', 'WorkHoursPerWeek']

scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome']] = scaler.fit_transform(df[['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome']])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome']] = scaler.fit_transform(df[['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome']])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.tokenize import word_tokenize
df['FeedbackTokenized'] = df['FeedbackComment'].apply(word_tokenize)

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
df['FeedbackCleaned'] = df['FeedbackTokenized'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df['FeedbackLemmatized'] = df['FeedbackCleaned'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
